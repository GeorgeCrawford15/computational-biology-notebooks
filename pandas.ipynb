# %% [markdown]
# ## DataFrame Basics

# %%
# %config Completer.use_jedi = False
import pandas as pd

df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns=["A", "B", "C"], index=["x", "y", "z"])

# %%
df.head() # Characters on the left are the indexes, and characters at the top are columns
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.tail(2)
# Out:
#    A  B  C
# y  4  5  6
# z  7  8  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
print(df.index)
print(df.index.tolist())
# Out:
# Index(['x', 'y', 'z'], dtype='object')
# ['x', 'y', 'z']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %% [markdown]
# df.describe()

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].nunique()
# Out:
# 3

# %%
df.shape # (number of rows, number of columns)
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %% [markdown]
# ## Loading/Manipulating Dataframes

# %%
coffee = pd.read_csv('./complete-pandas-tutorial/warmup-data/coffee.csv')
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_parquet('./complete-pandas-tutorial/data/results.parquet') # Will be using this dataset
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
olympics_data = pd.read_excel('./complete-pandas-tutorial/data/olympics-data.xlsx', sheet_name="results")
olympics_data.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
bios = pd.read_csv('./complete-pandas-tutorial/data/bios.csv') # Will also be using this dataset
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
coffee.sample(10, random_state=1) # Random set of data; setting random_state to 1 makes it deterministic and thus the same each time
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 4   Wednesday    Espresso          35
# 1      Monday       Latte          15
# 12     Sunday    Espresso          45
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35

# %%
display(coffee) # display() looks nicer than print()
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# ## Loc and iloc

# %%
# loc syntax: dataset.loc[rows, columns]
display(coffee.loc[0]) # Shows the first row
display(coffee.loc[[0, 1, 2]]) # Shows the first three rows
display(coffee.loc[5:12]) # Shows a set of rows from index 5 to 12 (loc includes the upper bound)
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45

# %%
coffee.loc[5:8, ["Day", "Units Sold"]] # Shows rows 5-8 and the info in columns "Day" and "Units Sold"
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45

# %%
# iloc only uses indexing and slicing
# Unlike loc, iloc EXCLUDES the upper bound
coffee.iloc[0:5, [0, 2]] # Shows rows 1-4, the info in the column with index 0, and the info in the column with index 2
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
# To get the index of a dataset:
coffee.index
# Out:
# Index(['Monday', 'Monday', 'Tuesday', 'Tuesday', 'Wednesday', 'Wednesday',
#        'Thursday', 'Thursday', 'Friday', 'Friday', 'Saturday', 'Saturday',
#        'Sunday', 'Sunday'],
#       dtype='object', name='Day')

# %%
# You can also change the indexes, in this case by assigning the values in the "Day" column as the new indexes:
coffee.index = coffee.Day
coffee.index = coffee["Day"]
# (These lines do the same thing)

# %%
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %%
# Since the row indexes are now days, not numbers, using number indexes with loc or iloc won't work:
coffee.loc[0:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 coffee.loc[0:4]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1411, in _LocIndexer._getitem_axis(self, key, axis)
#    1409 if isinstance(key, slice):
#    1410     self._validate_key(key, axis)
# -> 1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
#    1413     return self._getbool_axis(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1443, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1440     return obj.copy(deep=False)
#    1442 labels = obj._get_axis(axis)
# -> 1443 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1445 if isinstance(indexer, slice):
#    1446     return self.obj._slice(indexer, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6662, in Index.slice_indexer(self, start, end, step)
#    6618 def slice_indexer(
#    6619     self,
#    6620     start: Hashable | None = None,
#    6621     end: Hashable | None = None,
#    6622     step: int | None = None,
#    6623 ) -> slice:
#    6624     """
#    6625     Compute the slice indexer for input labels and step.
#    6626
#    (...)
#    6660     slice(1, 3, None)
#    6661     """
# -> 6662     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6664     # return a slice
#    6665     if not is_scalar(start_slice):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6879, in Index.slice_locs(self, start, end, step)
#    6877 start_slice = None
#    6878 if start is not None:
# -> 6879     start_slice = self.get_slice_bound(start, "left")
#    6880 if start_slice is None:
#    6881     start_slice = 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6794, in Index.get_slice_bound(self, label, side)
#    6790 original_label = label
#    6792 # For datetime indices label may be a string that has to be converted
#    6793 # to datetime boundary according to its resolution.
# -> 6794 label = self._maybe_cast_slice_bound(label, side)
#    6796 # we need to look up the label
#    6797 try:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6727, in Index._maybe_cast_slice_bound(self, label, side)
#    6725 # reject them, if index does not contain label
#    6726 if (is_float(label) or is_integer(label)) and label not in self:
# -> 6727     self._raise_invalid_indexer("slice", label)
#    6729 return label
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4301, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4299 if reraise is not lib.no_default:
#    4300     raise TypeError(msg) from reraise
# -> 4301 raise TypeError(msg)
#
# TypeError: cannot do slice indexing on Index with these indexers [0] of type int

# %%
# But the benefit is that now you can filter through the data more easily; in this case, I can now filter only the rows that have Monday
display(coffee.loc["Monday"])
# Or I can find a subset of rows ranging from those with index "Monday" to those with index "Wednesday" 
coffee.loc["Monday":"Wednesday"]
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso          25
# Monday  Monday       Latte          15
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25

# %%
coffee = pd.read_csv('./complete-pandas-tutorial/warmup-data/coffee.csv') # Reloading the dataset so we get the numerical indexes again
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
# You can use loc and iloc to change specific values in the dataset.
# i.e. change the number of lattes sold on Monday from 15 to 10:
coffee.loc[1, "Units Sold"] = 10
coffee.loc[1]
# Out:
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object

# %%
# Set multiple values to 6:
coffee.loc[0:2, "Units Sold"] = 6
coffee.loc[0:2]
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso           6
# 1      Monday       Latte           6
# 2     Tuesday    Espresso           6
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# at and iat get SINGULAR values (like loc and iloc, at uses row and column labels, while iat uses only integer values)
coffee.at[0, "Units Sold"]
# Out:
# np.int64(6)

# %%
coffee.iat[0, 0]
# Out:
# 'Monday'

# %% [markdown]
# ## Accessing Data | Grab Columns, Sort Values, Ascending/Descending

# %%
coffee = pd.read_csv('./complete-pandas-tutorial/warmup-data/coffee.csv') # Reloading the dataset so it's back to normal
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.sort_values("Units Sold") # Sorts the dataset by the values in "Units Sold" in ascending order by default
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 13     Sunday       Latte          35
# 11   Saturday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values("Units Sold", ascending=False) # To arrange in descending order
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 9      Friday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[0, 1]) 
# This first sorts by "Units Sold" in descending order.
# Then, if there are any rows with the same "Units Sold" value, they will be sorted in ascending order.
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
# To see more, look at rows 2 and 7 above. Currently, 2 is before 7 because Espresso is before Latte alphabetically
# Now look below, where 7 is before 2 because the "Coffee Type" row was sorted in descending order instead:
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[0, 0])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
# You can also iterate through the rows using a for loop with iterrows():
for index, row in coffee.iterrows():
    print(index)
    print(row)
    print("\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
#
#
# 9
# Day            Friday
# Coffee Type     Latte
# Units Sold         35
# Name: 9, dtype: object
#
#
# 10
# Day            Saturday
# Coffee Type    Espresso
# Units Sold           45
# Name: 10, dtype: object
#
#
# 11
# Day            Saturday
# Coffee Type       Latte
# Units Sold           35
# Name: 11, dtype: object
#
#
# 12
# Day              Sunday
# Coffee Type    Espresso
# Units Sold           45
# Name: 12, dtype: object
#
#
# 13
# Day            Sunday
# Coffee Type     Latte
# Units Sold         35
# Name: 13, dtype: object

# %%
# This is also helpful to quickly get a specific column value in each row with the corresponding row index:

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row["Units Sold"])
    print("\n")
# Out:
# 0
# 25
#
#
# 1
# 15
#
#
# 2
# 30
#
#
# 3
# 20
#
#
# 4
# 35
#
#
# 5
# 25
#
#
# 6
# 40
#
#
# 7
# 30
#
#
# 8
# 45
#
#
# 9
# 35
#
#
# 10
# 45
#
#
# 11
# 35
#
#
# 12
# 45
#
#
# 13
# 35

# %%
# This is usually faster though
coffee["Units Sold"]
# Out:
# 0     25
# 1     15
# 2     30
# 3     20
# 4     35
# 5     25
# 6     40
# 7     30
# 8     45
# 9     35
# 10    45
# 11    35
# 12    45
# 13    35
# Name: Units Sold, dtype: int64

# %% [markdown]
# ## Filtering Data - Using Olympic Data

# %%
# Let's filter the olympic bios dataset by height and weight.
bios.head()
# Do .info() to see what data types the height and weight columns hold
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
# Filter to get all athletes taller than 215 cm
bios.loc[bios['height_cm'] > 215, ['name', 'height_cm']] # Specifed which columns to show so the output is simpler
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %%
# A simpler way to filter this is just:
bios[bios['height_cm'] > 215][['name', 'height_cm']] # This is typical Pandas syntax: df[row/condition that selects various rows][selected column(s) from the row(s)]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %%
# You can also add additional conditions to filter even more:
bios[(bios['height_cm'] > 215) & (bios['born_country'] == 'USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios['name'].str.contains('Keith')] 
# This shows all the rows with the substring 'Keith' in the 'name' column
# Use case=false as a second argument within contains() to make it case-insensitive
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# 1897                  NaN          NaN        Ireland        NaN        NaN
# 3505              England          GBR  Great Britain      165.0       51.0
# 6228     British Columbia          CAN         Canada      200.0       85.0
# 8898                  NaN          NaN         Zambia        NaN        NaN
# 12053             England          GBR  Great Britain        NaN        NaN
# ...                   ...          ...            ...        ...        ...
# 109900         Canterbury          NZL    New Zealand        NaN        NaN
# 115973      Massachusetts          USA  United States      183.0       95.0
# 117676           Manitoba          CAN         Canada      185.0       88.0
# 122121           Victoria          AUS      Australia      176.0       78.0
# 127310  Manawatu-Wanganui          NZL   Cook Islands      167.0       60.0
#
#          died_date
# 1897           NaN
# 3505    1999-12-31
# 6228           NaN
# 8898    1993-01-09
# 12053   1973-02-22
# ...            ...
# 109900  2013-11-15
# 115973         NaN
# 117676         NaN
# 122121         NaN
# 127310         NaN
#
# [70 rows x 10 columns]

# %%
bios[bios['name'].str.contains('keith|patrick', case=False)] # This uses regular expressions to show all rows whose 'name' has Keith OR Patrick in it
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 1897          1907       Keith Hanlon  1966-09-01                    NaN
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# 6               Essonne          FRA         France      180.0       73.0
# 119       KwaZulu-Natal          RSA  Great Britain        NaN        NaN
# 319     Oost-Vlaanderen          BEL        Belgium      178.0       92.0
# 1897                NaN          NaN        Ireland        NaN        NaN
# 2115                NaN          NaN    Switzerland      176.0       67.0
# ...                 ...          ...            ...        ...        ...
# 143975              NaN          NaN         Zambia        NaN        NaN
# 144172            Tirol          AUT        Austria        NaN        NaN
# 144547       Syddanmark          DEN        Denmark        NaN        NaN
# 144565      Hovedstaden          DEN        Denmark      186.0       93.0
# 145435         Illinois          USA  United States        NaN        NaN
#
#          died_date
# 6              NaN
# 119     1967-11-05
# 319            NaN
# 1897           NaN
# 2115           NaN
# ...            ...
# 143975         NaN
# 144172         NaN
# 144547         NaN
# 144565         NaN
# 145435  2023-06-12
#
# [303 rows x 10 columns]

# %%
bios[bios['born_country'].isin(['USA', 'FRA', 'GBR'])]
# .isin(['x', 'y', 'z']) checks if any of the values in the specified column (the values in 'born_country' in this case) 
# are in -- or are equal to any of the values in -- the list within the .isin() parentheses
# Out:
#         athlete_id                   name   born_date      born_city  \
# 0                1  Jean-François Blanchy  1886-12-12       Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01         Meulan
# 2                3           Jean Borotra  1898-08-13       Biarritz
# 3                4        Jacques Brugnon  1895-05-11    Paris VIIIe
# 4                5           Albert Canet  1878-04-17     Wandsworth
# ...            ...                    ...         ...            ...
# 145454      149180          Anna Hoffmann  2000-03-28        Madison
# 145457      149183         Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145467      149194            Elisa Nakab  1998-05-08       Briançon
# 145468      149195      Justin Abdelkader  1987-02-25       Muskegon
# 145498      149225         André Foussard  1899-05-19          Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# 1                   Yvelines          FRA         France      183.0
# 2       Pyrénées-Atlantiques          FRA         France      183.0
# 3                      Paris          FRA         France      168.0
# 4                    England          GBR         France        NaN
# ...                      ...          ...            ...        ...
# 145454             Wisconsin          USA  United States        NaN
# 145457            California          USA  United States        NaN
# 145467          Hautes-Alpes          FRA          Italy        NaN
# 145468              Michigan          USA  United States      187.0
# 145498           Deux-Sèvres          FRA         France      166.0
#
#         weight_kg   died_date
# 0             NaN  1960-10-02
# 1            76.0         NaN
# 2            76.0  1994-07-17
# 3            64.0  1978-03-20
# 4             NaN  1930-07-25
# ...           ...         ...
# 145454        NaN         NaN
# 145457        NaN         NaN
# 145467        NaN         NaN
# 145468       97.0         NaN
# 145498        NaN  1986-03-18
#
# [20576 rows x 10 columns]

# %%
bios[bios['born_country'].isin(['USA', 'FRA', 'GBR']) & bios['name'].str.startswith('Keith')] # str.startswith() is good here to filter out any Keiths as last names
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# 57818        58226        Keith Peache  1947-08-10              Lewisham
# 61748        62202       Keith Grogono  1912-11-04             Stratford
# 62620        63086         Keith Musto  1936-01-12              Rochford
# 62678        63144        Keith Notary  1960-01-22        Merritt Island
# 68324        68841         Keith Angus  1943-04-05             Sheffield
# 68472        68989        Keith Cullen  1972-06-13                Ilford
# 68997        69514         Keith Stock  1957-03-18              Woolwich
# 77550        78141       Keith Brantly  1962-05-23  Scott Air Force Base
# 84097        84766  Keith Christiansen  1944-07-14   International Falls
# 94646        95413         Keith Meyer  1938-06-20                Geneva
# 95267        96037        Keith Oliver  1947-10-27             Liverpool
# 96452        97229  Keith Schellenberg  1929-03-13         Middlesbrough
# 97499        98286       Keith Tkachuk  1972-03-28               Melrose
# 98068        98860       Keith Wegeman  1929-08-28                Denver
# 99921       100722        Keith Carney  1970-02-03            Providence
# 115973      117348     Keith Sanderson  1975-02-02              Plymouth
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# 3505          England          GBR  Great Britain      165.0       51.0
# 12053         England          GBR  Great Britain        NaN        NaN
# 14577         England          GBR  Great Britain        NaN        NaN
# 16166         England          GBR  Great Britain      173.0       68.0
# 18734         England          GBR  Great Britain      190.0       79.0
# 29897         England          GBR  Great Britain      173.0       70.0
# 34011         England          GBR  Great Britain      193.0      114.0
# 46885         England          GBR  Great Britain      168.0       63.0
# 50929            Ohio          USA  United States        NaN        NaN
# 51185         Arizona          USA  United States      188.0       73.0
# 52913      California          USA  United States      196.0       86.0
# 55317         England          GBR  Great Britain      170.0       87.0
# 57818         England          GBR  Great Britain      180.0       98.0
# 61748         England          GBR  Great Britain        NaN        NaN
# 62620         England          GBR  Great Britain      174.0       72.0
# 62678         Florida          USA  United States      170.0       66.0
# 68324         England          GBR  Great Britain      170.0       59.0
# 68472         England          GBR  Great Britain      177.0       61.0
# 68997         England          GBR  Great Britain      176.0       73.0
# 77550        Illinois          USA  United States      180.0       64.0
# 84097       Minnesota          USA  United States      165.0       69.0
# 94646        Illinois          USA  United States        NaN        NaN
# 95267         England          GBR  Great Britain      172.0       68.0
# 96452         England          GBR  Great Britain        NaN        NaN
# 97499   Massachusetts          USA  United States      188.0      102.0
# 98068        Colorado          USA  United States        NaN        NaN
# 99921    Rhode Island          USA  United States      188.0       93.0
# 115973  Massachusetts          USA  United States      183.0       95.0
#
#          died_date
# 3505    1999-12-31
# 12053   1973-02-22
# 14577          NaN
# 16166          NaN
# 18734          NaN
# 29897          NaN
# 34011   2015-09-16
# 46885   1991-03-06
# 50929   2013-05-03
# 51185          NaN
# 52913          NaN
# 55317          NaN
# 57818          NaN
# 61748   1999-03-22
# 62620          NaN
# 62678          NaN
# 68324          NaN
# 68472          NaN
# 68997          NaN
# 77550          NaN
# 84097   2018-11-05
# 94646   2010-07-25
# 95267          NaN
# 96452   2019-10-28
# 97499          NaN
# 98068   1974-08-22
# 99921          NaN
# 115973         NaN

# %%
# .query() is another, somewhat faster way to filter 
bios.query('born_country == "USA" and born_city == "Madison"')
# Out:
#         athlete_id                        name   born_date born_city  \
# 16384        16500            Robert Schneider  1944-01-17   Madison
# 40154        40462                Carie Graves  1953-06-27   Madison
# 40216        40525                 Jackie Zoch  1949-06-08   Madison
# 40547        40856                  Chris Sahs  1970-07-09   Madison
# 46652        47001            Annabelle Cripps  1968-02-16   Madison
# 50746        51105              Helene Madison  1913-06-19   Madison
# 50989        51348               Steve Furniss  1952-12-21   Madison
# 51061        51420             Patrick Jeffrey  1965-06-24   Madison
# 51135        51494              Jim Montgomery  1955-01-24   Madison
# 51260        51619                   Paul Wolf  1915-10-05   Madison
# 52932        53307                Jeff Nygaard  1972-08-03   Madison
# 54555        54948          Harold McCallister  1903-10-14   Madison
# 60223        60655             Russ Hellickson  1948-05-29   Madison
# 60808        61247               Peter Barrett  1935-02-20   Madison
# 77365        77956               Michelle Rohl  1965-11-12   Madison
# 77570        78161                   Hal Brown  1898-03-30   Madison
# 78002        78593                Clare Jacobs  1886-02-18   Madison
# 78564        79155                  Gene Vidal  1895-04-13   Madison
# 80143        80794    Connie Carpenter-Phinney  1957-02-26   Madison
# 80289        80940  Dorcas DenHartog-Wonsavage  1965-02-03   Madison
# 80305        80956                 Mary Docter  1961-02-11   Madison
# 80306        80957                Sarah Docter  1964-05-10   Madison
# 80623        81274                 Beth Heiden  1959-09-27   Madison
# 81065        81717                   Kay Lunda  1957-04-28   Madison
# 81212        81864                   Lori Monk  1956-03-20   Madison
# 83306        83965                Marc Behrend  1961-01-11   Madison
# 83429        84090               Dave Besteman  1963-02-02   Madison
# 84272        84943               David Currier  1952-04-20   Madison
# 85869        86551                 Eric Heiden  1958-06-14   Madison
# 86645        87337               Dan Immerfall  1955-12-14   Madison
# 94856        95623               Peter Mueller  1954-07-27   Madison
# 95111        95880                Jeremy Nobis  1970-08-31   Madison
# 96062        96837               Barry Richter  1970-09-11   Madison
# 97022        97802                  Kurt Stein  1970-06-30   Madison
# 97198        97983                   Rob Suter  1957-05-16   Madison
# 98548        99344          Casey FitzRandolph  1975-01-21   Madison
# 99508       100307                 Erika Brown  1973-01-25   Madison
# 99915       100716                  Gary Suter  1964-06-24   Madison
# 101720      102649             Lindsay Tarpley  1983-09-22   Madison
# 117711      119236               Jessie Vetter  1985-12-19   Madison
# 117811      119347                 Phil Kessel  1987-10-02   Madison
# 117826      119366                  Ryan Suter  1985-01-21   Madison
# 126343      128694                 Craig Brown  1975-08-18   Madison
# 126381      128733               Amanda Kessel  1991-08-28   Madison
# 129416      132032         Heather Miller-Koch  1987-03-30   Madison
# 135117      138257                 Joanne Reid  1992-06-28   Madison
# 135136      138279              Becca Hamilton  1990-07-12   Madison
# 135138      138281                   Nina Roth  1988-07-21   Madison
# 135140      138283               Matt Hamilton  1989-02-19   Madison
# 143569      147222            Jessica Thoennes  1995-09-20   Madison
# 145364      149087              Gus Schumacher  2000-07-25   Madison
# 145454      149180               Anna Hoffmann  2000-03-28   Madison
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# 16384       Wisconsin          USA  United States      183.0       77.0
# 40154       Wisconsin          USA  United States      186.0       77.0
# 40216       Wisconsin          USA  United States      180.0       76.0
# 40547       Wisconsin          USA  United States      195.0       93.0
# 46652       Wisconsin          USA  Great Britain      180.0       66.0
# 50746       Wisconsin          USA  United States        NaN        NaN
# 50989       Wisconsin          USA  United States      193.0       80.0
# 51061      New Jersey          USA  United States      168.0       68.0
# 51135       Wisconsin          USA  United States      191.0       88.0
# 51260         Indiana          USA  United States        NaN        NaN
# 52932       Wisconsin          USA  United States      195.0       90.0
# 54555    South Dakota          USA  United States        NaN        NaN
# 60223       Wisconsin          USA  United States      180.0       95.0
# 60808       Wisconsin          USA  United States      184.0       88.0
# 77365       Wisconsin          USA  United States      150.0       41.0
# 77570      New Jersey          USA  United States      172.0       66.0
# 78002    South Dakota          USA  United States      178.0       64.0
# 78564    South Dakota          USA  United States      178.0       82.0
# 80143       Wisconsin          USA  United States      178.0       59.0
# 80289       Wisconsin          USA  United States      162.0       54.0
# 80305       Wisconsin          USA  United States      167.0       63.0
# 80306       Wisconsin          USA  United States      167.0       57.0
# 80623       Wisconsin          USA  United States      157.0       48.0
# 81065       Wisconsin          USA  United States      167.0       58.0
# 81212       Wisconsin          USA  United States      175.0       66.0
# 83306       Wisconsin          USA  United States      185.0       84.0
# 83429       Wisconsin          USA  United States      173.0       70.0
# 84272   New Hampshire          USA  United States      178.0       69.0
# 85869       Wisconsin          USA  United States      185.0       84.0
# 86645       Wisconsin          USA  United States      175.0       73.0
# 94856       Wisconsin          USA  United States      180.0       77.0
# 95111       Wisconsin          USA  United States      178.0       79.0
# 96062       Wisconsin          USA  United States      188.0       93.0
# 97022       Wisconsin          USA  United States      178.0       64.0
# 97198       Wisconsin          USA  United States      175.0       81.0
# 98548       Wisconsin          USA  United States      180.0       79.0
# 99508       Wisconsin          USA  United States      170.0       64.0
# 99915       Wisconsin          USA  United States      183.0       93.0
# 101720      Wisconsin          USA  United States      165.0       58.0
# 117711      Wisconsin          USA  United States      173.0       70.0
# 117811      Wisconsin          USA  United States      183.0       92.0
# 117826      Wisconsin          USA  United States      185.0       91.0
# 126343      Wisconsin          USA  United States      170.0       70.0
# 126381      Wisconsin          USA  United States      165.0       64.0
# 129416      Wisconsin          USA  United States      175.0       64.0
# 135117      Wisconsin          USA  United States      165.0       52.0
# 135136      Wisconsin          USA  United States      165.0       76.0
# 135138      Wisconsin          USA  United States      165.0       65.0
# 135140      Wisconsin          USA  United States      188.0       98.0
# 143569      Wisconsin          USA  United States      188.0        NaN
# 145364      Wisconsin          USA  United States        NaN        NaN
# 145454      Wisconsin          USA  United States        NaN        NaN
#
#          died_date
# 16384          NaN
# 40154   2021-12-19
# 40216          NaN
# 40547          NaN
# 46652          NaN
# 50746   1970-11-25
# 50989          NaN
# 51061          NaN
# 51135          NaN
# 51260   1972-10-14
# 52932          NaN
# 54555   1997-10-22
# 60223          NaN
# 60808   2000-12-17
# 77365          NaN
# 77570   1983-12-25
# 78002   1971-02-21
# 78564   1969-02-20
# 80143          NaN
# 80289          NaN
# 80305          NaN
# 80306          NaN
# 80623          NaN
# 81065          NaN
# 81212          NaN
# 83306          NaN
# 83429          NaN
# 84272          NaN
# 85869          NaN
# 86645          NaN
# 94856          NaN
# 95111   2023-04-19
# 96062          NaN
# 97022          NaN
# 97198   2014-09-09
# 98548          NaN
# 99508          NaN
# 99915          NaN
# 101720         NaN
# 117711         NaN
# 117811         NaN
# 117826         NaN
# 126343         NaN
# 126381         NaN
# 129416         NaN
# 135117         NaN
# 135136         NaN
# 135138         NaN
# 135140         NaN
# 143569         NaN
# 145364         NaN
# 145454         NaN

# %% [markdown]
# ## Adding/Removing Columns

# %%
# Returning to the coffee dataframe briefly, here's how you can add a new column:
coffee = pd.read_csv('./complete-pandas-tutorial/warmup-data/coffee.csv')
coffee['Price'] = 4.99
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          15   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
import numpy as np

coffee['New Price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99, 5.99) 
# np.where() takes a condition for each value of a specified column ('Coffee Type' in this case), a value that will be assigned to the corresponding row in the new 'New Price' column if
# the condition is true (3.99), and a value to be assigned if the condition is false (5.99).
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  New Price
# 0     Monday    Espresso          25   4.99       3.99
# 1     Monday       Latte          15   4.99       5.99
# 2    Tuesday    Espresso          30   4.99       3.99
# 3    Tuesday       Latte          20   4.99       5.99
# 4  Wednesday    Espresso          35   4.99       3.99

# %%
coffee.drop(columns=['Price'], inplace=True)
# .drop() can remove columns by putting the argument columns=['col1', 'col2' etc.] and you can apply this change by doing inplace=True 
# coffee = coffee.drop(columns=['Price']) also does the same thing

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  New Price
# 0     Monday    Espresso          25       3.99
# 1     Monday       Latte          15       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99

# %%
coffee_new = coffee.copy() # Do this every time you want to create a new version of a dataframe
coffee_new['Price'] = 4.99
coffee.head() # In doing so, you maintain the current state of the coffee dataframe (it's not mixed up with the state of coffee_new)
# Out:
#          Day Coffee Type  Units Sold  New Price
# 0     Monday    Espresso          25       3.99
# 1     Monday       Latte          15       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99

# %%
coffee = coffee[['Day', 'Coffee Type', 'Units Sold', 'New Price']] # This is another, slightly more tedious way of selecting certain columns
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  New Price
# 0     Monday    Espresso          25       3.99
# 1     Monday       Latte          15       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99

# %%
# Practical application: Adding a revenue column
coffee['Revenue'] = coffee['Units Sold'] * coffee['New Price']
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  New Price  Revenue
# 0     Monday    Espresso          25       3.99    99.75
# 1     Monday       Latte          15       5.99    89.85
# 2    Tuesday    Espresso          30       3.99   119.70
# 3    Tuesday       Latte          20       5.99   119.80
# 4  Wednesday    Espresso          35       3.99   139.65

# %%
coffee.rename(columns={'New Price': 'Price'}, inplace=True) # Renaming a column: columns argument takes a dictionary: {'current name of column': 'new name'}
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  Revenue
# 0     Monday    Espresso          25   3.99    99.75
# 1     Monday       Latte          15   5.99    89.85
# 2    Tuesday    Espresso          30   3.99   119.70
# 3    Tuesday       Latte          20   5.99   119.80
# 4  Wednesday    Espresso          35   3.99   139.65

# %%
# Moving back to bios data. Making a new bios dataframe to add a column with only first names
bios_new = bios.copy()
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0] # This takes all the names as strings, splits them into two chunks by the space between them, and selecting the first chunk
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date     first_name
# 0       1960-10-02  Jean-François
# 1              NaN         Arnaud
# 2       1994-07-17           Jean
# 3       1978-03-20        Jacques
# 4       1930-07-25         Albert
# ...            ...            ...
# 145495         NaN         Polina
# 145496         NaN       Valeriya
# 145497         NaN         Yuliya
# 145498  1986-03-18          André
# 145499  2003-10-20           Bill
#
# [145500 rows x 11 columns]

# %%
bios_new.query('first_name == "Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# 3505             England          GBR  Great Britain      165.0       51.0
# 6228    British Columbia          CAN         Canada      200.0       85.0
# 8898                 NaN          NaN         Zambia        NaN        NaN
# 12053            England          GBR  Great Britain        NaN        NaN
# ...                  ...          ...            ...        ...        ...
# 99921       Rhode Island          USA  United States      188.0       93.0
# 102227           Ontario          CAN         Canada      185.0       75.0
# 109900        Canterbury          NZL    New Zealand        NaN        NaN
# 115973     Massachusetts          USA  United States      183.0       95.0
# 122121          Victoria          AUS      Australia      176.0       78.0
#
#          died_date first_name
# 1897           NaN      Keith
# 3505    1999-12-31      Keith
# 6228           NaN      Keith
# 8898    1993-01-09      Keith
# 12053   1973-02-22      Keith
# ...            ...        ...
# 99921          NaN      Keith
# 102227         NaN      Keith
# 109900  2013-11-15      Keith
# 115973         NaN      Keith
# 122121         NaN      Keith
#
# [64 rows x 11 columns]

# %%
bios_new.info()
# Note that born_date is an object data type.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 12.2+ MB

# %%
# Use the Pandas .to_datetime() method to change the dates to datetime data types, as these are easier to work with.
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date']) # df['new_column (that will store dates as datetime Dtypes)'] = pd.to_datetime(df['original_column_with_dates'])
display(bios_new)
bios_new.info() # Now you can see the Dtype is datetime64
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date     first_name born_datetime  born_year
# 0       1960-10-02  Jean-François    1886-12-12     1886.0
# 1              NaN         Arnaud    1969-04-01     1969.0
# 2       1994-07-17           Jean    1898-08-13     1898.0
# 3       1978-03-20        Jacques    1895-05-11     1895.0
# 4       1930-07-25         Albert    1878-04-17     1878.0
# ...            ...            ...           ...        ...
# 145495         NaN         Polina    2002-01-30     2002.0
# 145496         NaN       Valeriya    1999-09-20     1999.0
# 145497         NaN         Yuliya    1998-05-08     1998.0
# 145498  1986-03-18          André    1899-05-19     1899.0
# 145499  2003-10-20           Bill    1913-07-15     1913.0
#
# [145500 rows x 13 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
#  12  born_year      143693 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(8)
# memory usage: 14.4+ MB

# %%
# Since the 'born_datetime' column holds datetime (or dt) Dtypes, there are a bunch of properties you can choose from -- just write df['column_with_dt_Dtypes'].dt. and press tab 
bios_new['born_year'] = bios_new['born_datetime'].dt.year
bios_new[['name', 'born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bios_new.to_csv('./complete-pandas-tutorial/data/bios_new.csv', index=False) # to_csv() saves this new dataframe in the data folder as a csv file
# Do index=False to get rid of the unnecessary index column that Pandas automatically adds

# %%
# You can use the apply() method to apply a lambda function that categorizes the data quickly
bios['height_category'] = bios['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Average' if x < 185 else 'Tall'))
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'Lightweight'
    elif row['height_cm'] < 185 or row['weight_kg'] <= 80:
        return 'Middleweight'
    else:
        return 'Heavyweight'

bios['category'] = bios.apply(categorize_athlete, axis=1) 
# apply() just applies a certain function to every row or column in a dataframe
# When axis=0, the function is applied to every column
# When axis=1, the function is applied to every row
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category
# 0  1960-10-02            Tall   Heavyweight
# 1         NaN         Average  Middleweight
# 2  1994-07-17         Average  Middleweight
# 3  1978-03-20         Average   Lightweight
# 4  1930-07-25            Tall   Heavyweight

# %%
categorize_athlete(bios.loc[1])
# Out:
# 'Middleweight'

# %% [markdown]
# ## Merging and Concatenating Data
# ## !! Add notes on how pd.merge() works

# %%
# Resetting bios dataframe
bios = pd.read_csv('./complete-pandas-tutorial/data/bios.csv')
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
nocs = pd.read_csv('./complete-pandas-tutorial/data/noc_regions.csv')
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new = pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='left')

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y born_country_full notes
# 0  1960-10-02   FRA            France   NaN
# 1         NaN   FRA            France   NaN
# 2  1994-07-17   FRA            France   NaN
# 3  1978-03-20   FRA            France   NaN
# 4  1930-07-25   GBR                UK   NaN

# %%
bios_new.rename(columns={'region': 'born_country_full'}, inplace=True)

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y born_country_full notes
# 0  1960-10-02   FRA            France   NaN
# 1         NaN   FRA            France   NaN
# 2  1994-07-17   FRA            France   NaN
# 3  1978-03-20   FRA            France   NaN
# 4  1930-07-25   GBR                UK   NaN

# %%
bios_new[bios_new['NOC_x'] != bios_new['born_country_full']][['name', 'NOC_x', 'born_country_full']]
# Out:
#                        name    NOC_x born_country_full
# 4              Albert Canet   France                UK
# 12                J. Defert   France               NaN
# 13           Étienne Durand   France               NaN
# 16               Guy Forget   France           Morocco
# 27       Guy, Baron Lejeune   France               NaN
# ...                     ...      ...               ...
# 145491        Matthew Wepke  Jamaica               NaN
# 145493   Landysh Falyakhova      ROC            Russia
# 145495    Polina Luchnikova      ROC            Russia
# 145496  Valeriya Merkusheva      ROC            Russia
# 145497      Yuliya Smirnova      ROC            Russia
#
# [73210 rows x 3 columns]

# %%
# Let's make two dataframes with just people born in the US and the UK
usa = bios[bios['born_country'] == 'USA'].copy()
gbr = bios[bios['born_country'] == 'GBR'].copy()
display(usa.head(3))
display(gbr.head(3))
# Out:
#      athlete_id               name   born_date    born_city born_region  \
# 54           55      Monique Javer  1967-07-22   Burlingame  California
# 960         964   Xóchitl Escobedo  1968-09-17  West Covina  California
# 961         965  Angélica Gavaldón  1973-10-03    El Centro  California
#
#     born_country            NOC  height_cm  weight_kg died_date
# 54           USA  Great Britain      177.0       64.0       NaN
# 960          USA         Mexico      170.0       60.0       NaN
# 961          USA         Mexico      160.0       54.0       NaN
#     athlete_id               name   born_date    born_city born_region  \
# 4            5       Albert Canet  1878-04-17   Wandsworth     England
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
#
#    born_country            NOC  height_cm  weight_kg   died_date
# 4           GBR         France        NaN        NaN  1930-07-25
# 37          GBR  Great Britain        NaN        NaN  1947-05-26
# 38          GBR  Great Britain        NaN        NaN  1972-05-10

# %%
# Now let's add one on top of the other by concatenating them with pd.concat([df1, df2])
new_df = pd.concat([usa, gbr])
new_df
# Out:
#         athlete_id                name   born_date         born_city  \
# 54              55       Monique Javer  1967-07-22        Burlingame
# 960            964    Xóchitl Escobedo  1968-09-17       West Covina
# 961            965   Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238      Bert Schneider  1897-07-01         Cleveland
# 1345          1352          Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                 ...         ...               ...
# 144811      148512  Benjamin Alexander  1983-05-08            London
# 144815      148517       Ashley Watson  1993-10-28      Peterborough
# 145005      148716     Peder Kongshaug  2001-08-13         Wimbledon
# 145319      149041          Axel Brown  1992-04-02         Harrogate
# 145388      149111      Jean-Luc Baker  1993-10-07           Burnley
#
#        born_region born_country                  NOC  height_cm  weight_kg  \
# 54      California          USA        Great Britain      177.0       64.0
# 960     California          USA               Mexico      170.0       60.0
# 961     California          USA               Mexico      160.0       54.0
# 1231          Ohio          USA               Canada        NaN        NaN
# 1345    California          USA        United States      168.0       61.0
# ...            ...          ...                  ...        ...        ...
# 144811     England          GBR              Jamaica        NaN        NaN
# 144815     England          GBR              Jamaica        NaN        NaN
# 145005     England          GBR               Norway      184.0       86.0
# 145319     England          GBR  Trinidad and Tobago        NaN        NaN
# 145388     England          GBR        United States        NaN        NaN
#
#          died_date
# 54             NaN
# 960            NaN
# 961            NaN
# 1231    1986-02-20
# 1345           NaN
# ...            ...
# 144811         NaN
# 144815         NaN
# 145005         NaN
# 145319         NaN
# 145388         NaN
#
# [15433 rows x 10 columns]

# %%
# Moving to results df
results = pd.read_csv('./complete-pandas-tutorial/data/results.csv')

# %%
results.tail()
# Out:
#           year    type              discipline                          event  \
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
#                           as  athlete_id  noc    team  place   tied medal
# 308403         Marián Skupek      148983  SVK     NaN   26.0  False   NaN
# 308404         Elsa Fermbäck      148984  SWE     NaN   28.0  False   NaN
# 308405         Hilma Lövblom      148985  SWE  Sweden   13.0  False   NaN
# 308406         Hilma Lövblom      148985  SWE     NaN    NaN  False   NaN
# 308407  Charlotta Säfvenberg      148986  NaN     NaN   24.0  False   NaN

# %%
combined_df = pd.merge(results, bios, on='athlete_id', how='left')
combined_df.tail()
# Out:
#           year    type              discipline                          event  \
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
#                           as  athlete_id  noc    team  place   tied medal  \
# 308403         Marián Skupek      148983  SVK     NaN   26.0  False   NaN
# 308404         Elsa Fermbäck      148984  SWE     NaN   28.0  False   NaN
# 308405         Hilma Lövblom      148985  SWE  Sweden   13.0  False   NaN
# 308406         Hilma Lövblom      148985  SWE     NaN    NaN  False   NaN
# 308407  Charlotta Säfvenberg      148986  NaN     NaN   24.0  False   NaN
#
#                         name   born_date   born_city born_region born_country  \
# 308403         Marián Skupek  2001-07-12     Gelnica      Košice          SVK
# 308404         Elsa Fermbäck  1998-03-28    Vemdalen    Jämtland          SWE
# 308405         Hilma Lövblom  2000-08-16        Täby   Stockholm          SWE
# 308406         Hilma Lövblom  2000-08-16        Täby   Stockholm          SWE
# 308407  Charlotta Säfvenberg  1994-10-07  Kungsbacka     Halland          SWE
#
#              NOC  height_cm  weight_kg died_date
# 308403  Slovakia      196.0      108.0       NaN
# 308404    Sweden        NaN        NaN       NaN
# 308405    Sweden        NaN        NaN       NaN
# 308406    Sweden        NaN        NaN       NaN
# 308407    Sweden        NaN        NaN       NaN

# %% [markdown]
# ## Handling Null Values

# %%
# Let's set two of the numbers in the 'Units Sold' column to null values by obtaining them via .loc, and setting them to np.nan
coffee.loc[[2, 3], 'Units Sold'] = np.nan
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso        25.0   3.99    99.75
# 1      Monday       Latte        15.0   5.99    89.85
# 2     Tuesday    Espresso         NaN   3.99   119.70
# 3     Tuesday       Latte         NaN   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
# Do this to see how many null values are in each column
coffee.isna().sum() # .isna() turns non-null values into False, and null values into True. .sum adds these up for each row
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# Price          0
# Revenue        0
# dtype: int64

# %%
# To handle null values, you can use .fillna() to replace them with something calculated from the existing data (or any value of your choice, but it's best to do the former)
coffee = coffee.fillna(coffee['Units Sold'].mean()) # In this case, each null value is replaced with the mean of the values in 'Units Sold'
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso   25.000000   3.99    99.75
# 1      Monday       Latte   15.000000   5.99    89.85
# 2     Tuesday    Espresso   34.166667   3.99   119.70
# 3     Tuesday       Latte   34.166667   5.99   119.80
# 4   Wednesday    Espresso   35.000000   3.99   139.65
# 5   Wednesday       Latte   25.000000   5.99   149.75
# 6    Thursday    Espresso   40.000000   3.99   159.60
# 7    Thursday       Latte   30.000000   5.99   179.70
# 8      Friday    Espresso   45.000000   3.99   179.55
# 9      Friday       Latte   35.000000   5.99   209.65
# 10   Saturday    Espresso   45.000000   3.99   179.55
# 11   Saturday       Latte   35.000000   5.99   209.65
# 12     Sunday    Espresso   45.000000   3.99   179.55
# 13     Sunday       Latte   35.000000   5.99   209.65

# %%
# .interpolate() is sometimes even better; it replaces nulls with values that continue the general trend of the rest of the values in the column
coffee.loc[[2, 3], 'Units Sold'] = np.nan # Putting in the null values again
coffee['Units Sold'] = coffee['Units Sold'].interpolate()
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso   25.000000   3.99    99.75
# 1      Monday       Latte   15.000000   5.99    89.85
# 2     Tuesday    Espresso   21.666667   3.99   119.70
# 3     Tuesday       Latte   28.333333   5.99   119.80
# 4   Wednesday    Espresso   35.000000   3.99   139.65
# 5   Wednesday       Latte   25.000000   5.99   149.75
# 6    Thursday    Espresso   40.000000   3.99   159.60
# 7    Thursday       Latte   30.000000   5.99   179.70
# 8      Friday    Espresso   45.000000   3.99   179.55
# 9      Friday       Latte   35.000000   5.99   209.65
# 10   Saturday    Espresso   45.000000   3.99   179.55
# 11   Saturday       Latte   35.000000   5.99   209.65
# 12     Sunday    Espresso   45.000000   3.99   179.55
# 13     Sunday       Latte   35.000000   5.99   209.65

# %%
# You can also use .dropna(), but that will drop any column that has null values entirely, so be careful with it
# i.e. coffee.dropna(inplace=True)
# i.e. coffee.dropna(subset=['Units Sold'], inplace=True) --> This only drops the 'Units Sold' column if it has null values

# %%
coffee.loc[[2, 3], 'Units Sold'] = np.nan # Putting in the null values again
display(coffee[coffee['Units Sold'].isna()]) # This returns all rows that have null values in the 'Units Sold' column
display(coffee[coffee['Units Sold'].notna()]) # This returns all rows that don't have null values in the 'Units Sold' column
# Out:
#        Day Coffee Type  Units Sold  Price  Revenue
# 2  Tuesday    Espresso         NaN   3.99    119.7
# 3  Tuesday       Latte         NaN   5.99    119.8
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso        25.0   3.99    99.75
# 1      Monday       Latte        15.0   5.99    89.85
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %% [markdown]
# ## Aggregating Data

# %%
display(bios.head())
bios['born_city'].value_counts() # .value_counts() adds up all the same values in a given column (in this case, the names of cities in the 'born_city' column)
# We can see from the data that Budapest produces the most Olympic athletes
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Kirovgrad             1
# Pereiaslav            1
# Podgornyy             1
# Kudepsta              1
# Furmanov              1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country'] == 'USA']['born_region'].value_counts() 
# This takes all the rows where the value in the 'born_country' column is 'USA', takes the values in the 'born_region' column of those rows, and adds values that are the same up
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Massachusetts            530
# Pennsylvania             530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# Vermont                   68
# Mississippi               66
# Alabama                   64
# Kentucky                  62
# Tennessee                 62
# Nebraska                  60
# Rhode Island              56
# Montana                   55
# Maine                     50
# South Carolina            50
# Alaska                    45
# Arkansas                  42
# Idaho                     41
# New Mexico                38
# Nevada                    36
# South Dakota              27
# West Virginia             24
# Delaware                  22
# North Dakota              16
# Wyoming                   14
# Name: count, dtype: int64

# %%
# Moving back to coffee data:
coffee.loc[[2, 3], ['Units Sold']] = [30, 20] # Getting rid of the nulls
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  Revenue
# 0     Monday    Espresso        25.0   3.99    99.75
# 1     Monday       Latte        15.0   5.99    89.85
# 2    Tuesday    Espresso        30.0   3.99   119.70
# 3    Tuesday       Latte        20.0   5.99   119.80
# 4  Wednesday    Espresso        35.0   3.99   139.65

# %%
# .groupby(['column whose values will serve as categories])['column whose values will be assigned to those categories based on which category they align with in the dataframe'].sum()
# i.e. in row 0 above, 25 espressos were sold. Since espressos are now grouped as a category, the corresponding value of 25 in the 'Units Sold' column is assigned to this group
# .sum() adds up all of these 'Units Sold' values assigned to each group/category
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    265.0
# Latte       195.0
# Name: Units Sold, dtype: float64

# %%
# You can do other things like take the mean of these grouped 'Units Sold' values as well (average number of espressos and lattes sold each day):
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    37.857143
# Latte       27.857143
# Name: Units Sold, dtype: float64

# %%
# Using .agg({dict}) allows you to perform various operations on different columns, all of whose values are grouped by the values in the 'Coffee Type' column
coffee.groupby(['Coffee Type']).agg({'Units Sold': 'sum', 'Price': 'mean'})
# Out:
#              Units Sold  Price
# Coffee Type
# Espresso          265.0   3.99
# Latte             195.0   5.99

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold': 'sum', 'Price': 'mean'})
# Out:
#              Units Sold  Price
# Coffee Type
# Espresso          265.0   3.99
# Latte             195.0   5.99

# %%
# .pivot(columns=[], index='', values='') is a great way to basically create a new dataframe from your original one
# Here, we make the values in the 'Coffee Type' column into columns themselves, make the values be the corresponding values in the 'Revenue' column, and make the index the corresponding days
pivot = coffee.pivot(columns='Coffee Type', index='Day', values='Revenue')
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         179.55  209.65
# Monday          99.75   89.85
# Saturday       179.55  209.65
# Sunday         179.55  209.65
# Thursday       159.60  179.70
# Tuesday        119.70  119.80
# Wednesday      139.65  149.75

# %%
# Now you can more easily access important data; for example, how much revenue you made from lattes on Monday:
pivot.loc['Monday', 'Latte']
# Out:
# np.float64(89.85000000000001)

# %%
# Total revenue from espressos and lattes
pivot.sum()
# Out:
# Coffee Type
# Espresso    1057.35
# Latte       1168.05
# dtype: float64

# %%
# Total revenue per day
pivot.sum(axis=1)
# Out:
# Day
# Friday       389.2
# Monday       189.6
# Saturday     389.2
# Sunday       389.2
# Thursday     339.3
# Tuesday      239.5
# Wednesday    289.4
# dtype: float64

# %%
# Moving to bios dataframe:
bios['born_date'] = pd.to_datetime(bios['born_date'])
bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index().sort_values('name', ascending=False)
# This groups by the year one was born, counts up the number of people (# of names) born in each year group, establishes a new index for each row, and sorts the counts from highest to lowest
# Out:
#      born_date  name
# 139     1972.0  2231
# 152     1985.0  2227
# 140     1973.0  2216
# 138     1971.0  2205
# 137     1970.0  2174
# ..         ...   ...
# 4       1837.0     1
# 2       1833.0     1
# 6       1839.0     1
# 12      1845.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %%
# You could even group by year first, and then divide those groups up into smaller groups by month:
bios['month_born'] = bios['born_date'].dt.month
bios['year_born'] = bios['born_date'].dt.year
bios.groupby([bios['year_born'], bios['month_born']])['name'].count().reset_index().sort_values('name', ascending=False)
# We now know that the most olympic athletes born was in January of 1970, for example:
# Out:
#       year_born  month_born  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1497     1975.0         1.0   227
# 1629     1986.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 1877     2006.0        12.0     1
# 1871     2006.0         3.0     1
# 20       1846.0         7.0     1
# 21       1846.0         8.0     1
# 22       1846.0         9.0     1
#
# [1885 rows x 3 columns]

# %% [markdown]
# ## Advanced Functionality

# %%
# Moving to coffee data:
# You can use .shift(number of times you shift down in rows) to do stuff like...
# Creating a new column that shows the revenue made from a certain type of coffee yesterday (this could be useful since you can easily compare how much you made from today vs yesterday)
coffee['Yesterday Revenue'] = coffee['Revenue'].shift(2) # Values are shifted down two rows since two rows represent one day in this dataframe 
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue  Yesterday Revenue
# 0      Monday    Espresso        25.0   3.99    99.75                NaN
# 1      Monday       Latte        15.0   5.99    89.85                NaN
# 2     Tuesday    Espresso        30.0   3.99   119.70              99.75
# 3     Tuesday       Latte        20.0   5.99   119.80              89.85
# 4   Wednesday    Espresso        35.0   3.99   139.65             119.70
# 5   Wednesday       Latte        25.0   5.99   149.75             119.80
# 6    Thursday    Espresso        40.0   3.99   159.60             139.65
# 7    Thursday       Latte        30.0   5.99   179.70             149.75
# 8      Friday    Espresso        45.0   3.99   179.55             159.60
# 9      Friday       Latte        35.0   5.99   209.65             179.70
# 10   Saturday    Espresso        45.0   3.99   179.55             179.55
# 11   Saturday       Latte        35.0   5.99   209.65             209.65
# 12     Sunday    Espresso        45.0   3.99   179.55             179.55
# 13     Sunday       Latte        35.0   5.99   209.65             209.65

# %%
coffee['Percent Change'] = coffee['Revenue'] / coffee['Yesterday Revenue'] * 100 - 100
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue  Yesterday Revenue  \
# 0      Monday    Espresso        25.0   3.99    99.75                NaN
# 1      Monday       Latte        15.0   5.99    89.85                NaN
# 2     Tuesday    Espresso        30.0   3.99   119.70              99.75
# 3     Tuesday       Latte        20.0   5.99   119.80              89.85
# 4   Wednesday    Espresso        35.0   3.99   139.65             119.70
# 5   Wednesday       Latte        25.0   5.99   149.75             119.80
# 6    Thursday    Espresso        40.0   3.99   159.60             139.65
# 7    Thursday       Latte        30.0   5.99   179.70             149.75
# 8      Friday    Espresso        45.0   3.99   179.55             159.60
# 9      Friday       Latte        35.0   5.99   209.65             179.70
# 10   Saturday    Espresso        45.0   3.99   179.55             179.55
# 11   Saturday       Latte        35.0   5.99   209.65             209.65
# 12     Sunday    Espresso        45.0   3.99   179.55             179.55
# 13     Sunday       Latte        35.0   5.99   209.65             209.65
#
#     Percent Change
# 0              NaN
# 1              NaN
# 2        20.000000
# 3        33.333333
# 4        16.666667
# 5        25.000000
# 6        14.285714
# 7        20.000000
# 8        12.500000
# 9        16.666667
# 10        0.000000
# 11        0.000000
# 12        0.000000
# 13        0.000000

# %%
# Moving to bios:
# .rank() basically just takes each value in a certain column, compares it to all the other columns, and assigns it a value
# In this case, it ranks the values in 'height_cm', where it assigns a bigger number for bigger values
bios['height_rank'] = bios['height_cm'].rank()
bios.sort_values(['height_rank'], ascending=False)
# Out:
#         athlete_id                   name  born_date           born_city  \
# 89070        89782               Yao Ming 1980-09-12      Xuhui District
# 6978          7013        Arvydas Sabonis 1964-12-19              Kaunas
# 5781          5804         Tommy Burleson 1952-02-24           Crossnore
# 89075        89787         Roberto Dueñas 1975-11-01              Madrid
# 120266      122147           Zhang Zhaoxu 1987-11-18             Binzhou
# ...            ...                    ...        ...                 ...
# 145490      149217            Sin Ye-Chan 1995-06-13                 NaN
# 145491      149218          Matthew Wepke 1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez 1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova 1998-08-31    Dva Polya Artash
# 145499      149814          Bill Phillips 1913-07-15        Dulwich Hill
#
#                  born_region born_country                         NOC  \
# 89070               Shanghai          CHN  People's Republic of China
# 6978                  Kaunas          LTU      Lithuania Soviet Union
# 5781          North Carolina          USA               United States
# 89075                 Madrid          ESP                       Spain
# 120266              Shandong          CHN  People's Republic of China
# ...                      ...          ...                         ...
# 145490                   NaN          NaN           Republic of Korea
# 145491                   NaN          NaN                     Jamaica
# 145492   Ciudad de La Habana          CUB                        Cuba
# 145493  Respublika Tatarstan          RUS                         ROC
# 145499       New South Wales          AUS                   Australia
#
#         height_cm  weight_kg   died_date  month_born  year_born  height_rank
# 89070       226.0      141.0         NaN         9.0     1980.0     106651.0
# 6978        223.0      122.0         NaN        12.0     1964.0     106649.5
# 5781        223.0      102.0         NaN         2.0     1952.0     106649.5
# 89075       221.0      137.0         NaN        11.0     1975.0     106647.0
# 120266      221.0      110.0         NaN        11.0     1987.0     106647.0
# ...           ...        ...         ...         ...        ...          ...
# 145490        NaN        NaN         NaN         6.0     1995.0          NaN
# 145491        NaN        NaN         NaN        12.0     1989.0          NaN
# 145492        NaN        NaN  2019-11-24         4.0     1927.0          NaN
# 145493        NaN        NaN         NaN         8.0     1998.0          NaN
# 145499        NaN        NaN  2003-10-20         7.0     1913.0          NaN
#
# [145500 rows x 13 columns]

# %%
# Moving back to coffee df:
coffee['Cumulative Revenue'] = coffee['Revenue'].cumsum() # .cumsum() --> cumulative sum
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue  Yesterday Revenue  \
# 0      Monday    Espresso        25.0   3.99    99.75                NaN
# 1      Monday       Latte        15.0   5.99    89.85                NaN
# 2     Tuesday    Espresso        30.0   3.99   119.70              99.75
# 3     Tuesday       Latte        20.0   5.99   119.80              89.85
# 4   Wednesday    Espresso        35.0   3.99   139.65             119.70
# 5   Wednesday       Latte        25.0   5.99   149.75             119.80
# 6    Thursday    Espresso        40.0   3.99   159.60             139.65
# 7    Thursday       Latte        30.0   5.99   179.70             149.75
# 8      Friday    Espresso        45.0   3.99   179.55             159.60
# 9      Friday       Latte        35.0   5.99   209.65             179.70
# 10   Saturday    Espresso        45.0   3.99   179.55             179.55
# 11   Saturday       Latte        35.0   5.99   209.65             209.65
# 12     Sunday    Espresso        45.0   3.99   179.55             179.55
# 13     Sunday       Latte        35.0   5.99   209.65             209.65
#
#     Percent Change  Cumulative Revenue
# 0              NaN               99.75
# 1              NaN              189.60
# 2        20.000000              309.30
# 3        33.333333              429.10
# 4        16.666667              568.75
# 5        25.000000              718.50
# 6        14.285714              878.10
# 7        20.000000             1057.80
# 8        12.500000             1237.35
# 9        16.666667             1447.00
# 10        0.000000             1626.55
# 11        0.000000             1836.20
# 12        0.000000             2015.75
# 13        0.000000             2225.40

# %%
latte = coffee[coffee['Coffee Type'] == 'Latte'].copy()
latte['3day'] = latte['Units Sold'].rolling(3).sum() # This moves through each row, gets the last three revenue values, adds them up, and adds that value to the current row in the '3day' column
# .rolling(last # of rows to obtain values from) basically just gets the values from the last few rows (a number would be specified -- values from last two rows, last three, etc.)
latte
# Below: 60 = 15 + 20 + 25; 75 = 20 + 25 + 30; etc.
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue  Yesterday Revenue  \
# 1      Monday       Latte        15.0   5.99    89.85                NaN
# 3     Tuesday       Latte        20.0   5.99   119.80              89.85
# 5   Wednesday       Latte        25.0   5.99   149.75             119.80
# 7    Thursday       Latte        30.0   5.99   179.70             149.75
# 9      Friday       Latte        35.0   5.99   209.65             179.70
# 11   Saturday       Latte        35.0   5.99   209.65             209.65
# 13     Sunday       Latte        35.0   5.99   209.65             209.65
#
#     Percent Change  Cumulative Revenue   3day
# 1              NaN               189.6    NaN
# 3        33.333333               429.1    NaN
# 5        25.000000               718.5   60.0
# 7        20.000000              1057.8   75.0
# 9        16.666667              1447.0   90.0
# 11        0.000000              1836.2  100.0
# 13        0.000000              2225.4  105.0
